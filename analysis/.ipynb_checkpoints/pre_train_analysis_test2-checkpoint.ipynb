# %%
import sys
import ast
import json
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer
import sys
import pickle
from rouge_score import rouge_scorer
from rouge_score import scoring
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy
from scipy.stats import ttest_ind

# %%
# from scipy.stats import ttest_ind

# cat1 = my_data[my_data['Category']=='cat1']
# cat2 = my_data[my_data['Category']=='cat2']

# ttest_ind(cat1['values'], cat2['values'])
# >>> (1.4927289925706944, 0.16970867501294376)

# %% [markdown]
# ## Baseline: Longformer2Roberta trained on 40k standard pubmed documents

# %%
pubmed_results_df = pd.read_csv('../results/pre_trained_pubmed/summaries_test_model1.csv')
pubmed_results_df.head()
# Out:
#    Unnamed: 0                                           abstract  \
# 0           0   research on the implications of anxiety in pa...
# 1           1   small non - coding rnas include sirna , mirna...
# 2           2   objective : to evaluate the efficacy and safe...
# 3           3   congenital adrenal hyperplasia is a group of ...
# 4           4   objective(s):pentoxifylline is an immunomodul...
#
#                                              article  \
# 0  anxiety affects quality of life in those livin...
# 1  small non - coding rnas are transcribed into m...
# 2  ohss is a serious complication of ovulation in...
# 3  congenital adrenal hyperplasia ( cah ) refers ...
# 4  type 1 diabetes ( t1d ) results from the destr...
#
#                                             pred_new  \
# 0   objectiveto investigate the effects of anxiet...
# 1   mir-17/22/16, a novel gene that regulates the...
# 2   \n objective. to evaluate the role of pigtail...
# 3   objective : to report the clinical presentati...
# 4   the present study aimed to investigate the im...
#
#                                        section_names
# 0  1. Introduction\n2. Methods\n3. Results\n4. Di...
# 1  Introduction\nAberrant Expression of miRNA in ...
# 2  Introduction\nMaterials and Methods\nResults\n...
# 3                                         I\nM\nR\nD
# 4  Introduction\nMaterials and Methods\nDrug and ...

# %%
# rank summaries
r1 = []
r2 = []
rlsum = []
# initialize scorer
scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeLsum"], use_stemmer=True)
# iterate and score each document
for i in range(len(pubmed_results_df)):
    pred = pubmed_results_df.pred_new[i]
    ref = pubmed_results_df.abstract[i]
    score = scorer.score(ref, pred)
    r1.append(score['rouge1'].fmeasure)
    r2.append(score['rouge2'].fmeasure)
    rlsum.append(score['rougeLsum'].fmeasure)
# add scores to dataframe
pubmed_results_df['r1'] = r1
pubmed_results_df['r2'] = r2
pubmed_results_df['rlsum'] = rlsum

# %%
pubmed_results_df.describe()
# Out:
#         Unnamed: 0           r1           r2        rlsum
# count  6658.000000  6658.000000  6658.000000  6658.000000
# mean   3328.500000     0.292444     0.081956     0.264025
# std    1922.143378     0.071614     0.046239     0.064865
# min       0.000000     0.000000     0.000000     0.000000
# 25%    1664.250000     0.243655     0.049055     0.219330
# 50%    3328.500000     0.292023     0.076023     0.262295
# 75%    4992.750000     0.339838     0.108108     0.307242
# max    6657.000000     0.566667     0.368932     0.537445

# %%
# plot distributions for each metric
fig, ax = plt.subplots(1,3,figsize=(15,3))
ax[0].hist(pubmed_results_df['r1'], bins=100)
ax[0].set_title('rouge-1 distribution')
ax[1].hist(pubmed_results_df['r2'], bins=100)
ax[1].set_title('rouge-2 distribution')
ax[2].hist(pubmed_results_df['rlsum'], bins=100)
ax[2].set_title('rouge-Lsum distribution')
pass

# %% [markdown]
# ## Experiment 1: Longformer2Roberta trained on 40k ranked pubmed documents

# %%
ranked_pubmed_results_df = pd.read_csv('../results/pre_trained_ranked_pubmed/summaries_rank_test_model3.csv')
ranked_pubmed_results_df.head()
# Out:
#    Unnamed: 0  __index_level_0__  \
# 0           0                  0
# 1           1                  1
# 2           2                  2
# 3           3                  3
# 4           4                  4
#
#                                                 pred  \
# 0  <S> anxiety is a major public health problem i...
# 1  <S> cancer is a complex disease that is caused...
# 2  <S> the aim of this study was to describe a ne...
# 3  <S> objective : to report the clinical present...
# 4  <S> the development of several autoimmune dise...
#
#                                               target  \
# 0  <S> research on the implications of anxiety in...
# 1  <S> small non - coding rnas include sirna , mi...
# 2  <S> objective : to evaluate the efficacy and s...
# 3  <S> congenital adrenal hyperplasia is a group ...
# 4  <S> objective(s):pentoxifylline is an immunomo...
#
#                                                 text
# 0  self - reported hads was used to assess anxiet...
# 1  although the tendency for a global decrease of...
# 2  patients with critical ohss and those with per...
# 3  short stature was seen in one third of patient...
# 4  all stz - induced diabetic mice with ptx treat...

# %%
# rank summaries
r1 = []
r2 = []
rlsum = []
# initialize scorer
scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeLsum"], use_stemmer=True)
# iterate and score each document
for i in range(len(ranked_pubmed_results_df)):
    pred = ranked_pubmed_results_df.pred[i]
    ref = ranked_pubmed_results_df.target[i]
    score = scorer.score(ref, pred)
    r1.append(score['rouge1'].fmeasure)
    r2.append(score['rouge2'].fmeasure)
    rlsum.append(score['rougeLsum'].fmeasure)
# add scores to dataframe
ranked_pubmed_results_df['r1'] = r1
ranked_pubmed_results_df['r2'] = r2
ranked_pubmed_results_df['rlsum'] = rlsum

# %%
ranked_pubmed_results_df.describe()
# Out:
#         Unnamed: 0  __index_level_0__           r1           r2        rlsum
# count  6658.000000        6658.000000  6658.000000  6658.000000  6658.000000
# mean   3328.500000        3328.500000     0.323933     0.098607     0.205586
# std    1922.143378        1922.143378     0.068387     0.042954     0.047775
# min       0.000000           0.000000     0.043478     0.000000     0.034783
# 25%    1664.250000        1664.250000     0.280374     0.068376     0.173913
# 50%    3328.500000        3328.500000     0.325733     0.094017     0.200692
# 75%    4992.750000        4992.750000     0.369811     0.124224     0.230303
# max    6657.000000        6657.000000     0.588957     0.357895     0.475096

# %%
# plot distributions for each metric
fig, ax = plt.subplots(1,3,figsize=(15,3))
ax[0].hist(ranked_pubmed_results_df['r1'], bins=100)
ax[0].set_title('rouge-1 distribution')
ax[1].hist(ranked_pubmed_results_df['r2'], bins=100)
ax[1].set_title('rouge-2 distribution')
ax[2].hist(ranked_pubmed_results_df['rlsum'], bins=100)
ax[2].set_title('rouge-Lsum distribution')
pass

# %% [markdown]
# ## Experiment 2: Longformer2Roberta trained on 40k ranked and temporally corrected pubmed documents

# %%
ranked_temporal_pubmed_results_df = pd.read_csv('../results/pre_trained_ranked_temporal_pubmed/summaries_rank_temporal_test_model2.csv')
ranked_temporal_pubmed_results_df.head()
# Out:
#    Unnamed: 0  __index_level_0__  \
# 0           0                  0
# 1           1                  1
# 2           2                  2
# 3           3                  3
# 4           4                  4
#
#                                             pred_new  \
# 0  <S> objective : to investigate the effects of ...
# 1  <S> mirna is a class of cancer - specific canc...
# 2  <S> objective : to describe the management of ...
# 3  <S> objective : to report the clinical present...
# 4  <S> objectiveto investigate the effects of the...
#
#                                               target  \
# 0  <S> research on the implications of anxiety in...
# 1  <S> small non - coding rnas include sirna , mi...
# 2  <S> objective : to evaluate the efficacy and s...
# 3  <S> congenital adrenal hyperplasia is a group ...
# 4  <S> objective(s):pentoxifylline is an immunomo...
#
#                                                 text
# 0  self - reported hads was used to assess anxiet...
# 1  although the tendency for a global decrease of...
# 2  patients with critical ohss and those with per...
# 3  short stature was seen in one third of patient...
# 4  all stz - induced diabetic mice with ptx treat...

# %%
# rank summaries
r1 = []
r2 = []
rlsum = []
# initialize scorer
scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeLsum"], use_stemmer=True)
# iterate and score each document
for i in range(len(ranked_temporal_pubmed_results_df)):
    pred = ranked_temporal_pubmed_results_df.pred_new[i]
    ref = ranked_temporal_pubmed_results_df.target[i]
    score = scorer.score(ref, pred)
    r1.append(score['rouge1'].fmeasure)
    r2.append(score['rouge2'].fmeasure)
    rlsum.append(score['rougeLsum'].fmeasure)
# add scores to dataframe
ranked_temporal_pubmed_results_df['r1'] = r1
ranked_temporal_pubmed_results_df['r2'] = r2
ranked_temporal_pubmed_results_df['rlsum'] = rlsum

# %%
ranked_temporal_pubmed_results_df.describe()
# Out:
#         Unnamed: 0  __index_level_0__           r1           r2        rlsum
# count  6658.000000        6658.000000  6658.000000  6658.000000  6658.000000
# mean   3328.500000        3328.500000     0.319332     0.098131     0.202814
# std    1922.143378        1922.143378     0.067195     0.044460     0.050209
# min       0.000000           0.000000     0.056338     0.000000     0.056338
# 25%    1664.250000        1664.250000     0.274773     0.066999     0.169492
# 50%    3328.500000        3328.500000     0.319328     0.092400     0.197386
# 75%    4992.750000        4992.750000     0.363636     0.123348     0.227273
# max    6657.000000        6657.000000     0.554913     0.404762     0.528302

# %%
# plot distributions for each metric
fig, ax = plt.subplots(1,3,figsize=(15,3))
ax[0].hist(ranked_temporal_pubmed_results_df['r1'], bins=100)
ax[0].set_title('rouge-1 distribution')
ax[1].hist(ranked_temporal_pubmed_results_df['r2'], bins=100)
ax[1].set_title('rouge-2 distribution')
ax[2].hist(ranked_temporal_pubmed_results_df['rlsum'], bins=100)
ax[2].set_title('rouge-Lsum distribution')
pass

# %% [markdown]
# ## Generate Lengths

# %%
# Import test data
with open('../data/json_test.txt') as json_file:
    test = json.load(json_file)
test = test['data']

tokenizer = AutoTokenizer.from_pretrained("allenai/longformer-base-4096", add_prefix_space=True)
doc_len = []
for i in test:
    input_ = i['article_text']
    length = len(tokenizer(input_, is_split_into_words=True, return_tensors='pt', truncation=False)[0])
    doc_len.append(length)

pubmed_results_df['doc_len'] = doc_len
ranked_pubmed_results_df['doc_len'] = doc_len
ranked_temporal_pubmed_results_df['doc_len'] = doc_len

# %% [markdown]
# ## Statistical tests, and distribution overlay (ranked vs original)

# %%
# plot distributions for each metric
fig, ax = plt.subplots(1,3,figsize=(20,5))
kwargs = {'alpha':0.7, 'bins':100}
ax[0].hist(pubmed_results_df['r1'], **kwargs, label='pubmed')
ax[0].hist(ranked_pubmed_results_df['r1'], **kwargs, label='ranked pubmed')
ax[0].legend()
ax[0].set_title('rouge-1 distribution')
ax[1].hist(pubmed_results_df['r2'], **kwargs, label='pubmed')
ax[1].hist(ranked_pubmed_results_df['r2'], **kwargs, label='ranked pubmed')
ax[1].set_title('rouge-2 distribution')
ax[1].legend()
ax[2].hist(pubmed_results_df['rlsum'], **kwargs, label='pubmed')
ax[2].hist(ranked_pubmed_results_df['rlsum'], **kwargs, label='ranked pubmed')
ax[2].set_title('rouge-Lsum distribution')
ax[2].legend()
plt.suptitle('Rouge Scores, Pre-Trained on Pubmed vs. Ranked Pubmed', y=1.05, size=16)
pass

# %%
# t-tests
print('overall:')
df1 = pubmed_results_df
df2 = ranked_pubmed_results_df
r1_pubmed = df1['r1']
r1_ranked = df2['r1']
r1_t_test = ttest_ind(r1_pubmed, r1_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-1 t-test:\n{r1_t_test}')
print('----')
r2_pubmed = df1['r2']
r2_ranked = df2['r2']
r2_t_test = ttest_ind(r2_pubmed, r2_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-2 t-test:\n{r2_t_test}')
print('----')
rl_pubmed = df1['rlsum']
rl_ranked = df2['rlsum']
rl_t_test = ttest_ind(rl_pubmed, rl_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-Lsum t-test:\n{rl_t_test}')
print('\n')

# long documents
print('documents > 4096 tokens:')
df1 = pubmed_results_df[pubmed_results_df['doc_len'] > 4096]
df2 = ranked_pubmed_results_df[ranked_pubmed_results_df['doc_len'] > 4096]
r1_pubmed = df1['r1']
r1_ranked = df2['r1']
r1_t_test = ttest_ind(r1_pubmed, r1_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-1 t-test:\n{r1_t_test}')
print('----')
r2_pubmed = df1['r2']
r2_ranked = df2['r2']
r2_t_test = ttest_ind(r2_pubmed, r2_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-2 t-test:\n{r2_t_test}')
print('----')
rl_pubmed = df1['rlsum']
rl_ranked = df2['rlsum']
rl_t_test = ttest_ind(rl_pubmed, rl_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-Lsum t-test:\n{rl_t_test}')
print('\n')

# short documents
print('documents < 4096 tokens:')
df1 = pubmed_results_df[pubmed_results_df['doc_len'] < 4096]
df2 = ranked_pubmed_results_df[ranked_pubmed_results_df['doc_len'] < 4096]
r1_pubmed = df1['r1']
r1_ranked = df2['r1']
r1_t_test = ttest_ind(r1_pubmed, r1_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-1 t-test:\n{r1_t_test}')
print('----')
r2_pubmed = df1['r2']
r2_ranked = df2['r2']
r2_t_test = ttest_ind(r2_pubmed, r2_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-2 t-test:\n{r2_t_test}')
print('----')
rl_pubmed = df1['rlsum']
rl_ranked = df2['rlsum']
rl_t_test = ttest_ind(rl_pubmed, rl_ranked, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-Lsum t-test:\n{rl_t_test}')
print('\n')
print(len(df1))
print(len(df2))
# Out:
# overall:
# Results for Rouge-1 t-test:
# Ttest_indResult(statistic=-25.9477489011517, pvalue=7.581677531613236e-145)
# ----
# Results for Rouge-2 t-test:
# Ttest_indResult(statistic=-21.527206599548162, pvalue=4.631706434453056e-101)
# ----
# Results for Rouge-Lsum t-test:
# Ttest_indResult(statistic=59.1914458686743, pvalue=0.0)
#
#
# documents > 4096 tokens:
# Results for Rouge-1 t-test:
# Ttest_indResult(statistic=-14.387222968092287, pvalue=5.876432022142776e-46)
# ----
# Results for Rouge-2 t-test:
# Ttest_indResult(statistic=-14.407141289911472, pvalue=4.4929206822961634e-46)
# ----
# Results for Rouge-Lsum t-test:
# Ttest_indResult(statistic=34.50431395260774, pvalue=7.291256587469601e-231)
#
#
# documents < 4096 tokens:
# Results for Rouge-1 t-test:
# Ttest_indResult(statistic=-22.099232856052883, pvalue=2.6851347706313547e-105)
# ----
# Results for Rouge-2 t-test:
# Ttest_indResult(statistic=-16.795032569485535, pvalue=2.613715306607074e-62)
# ----
# Results for Rouge-Lsum t-test:
# Ttest_indResult(statistic=48.80458159695478, pvalue=0.0)
#
#
# 4316
# 4316

# %% [markdown]
# ## Statistical tests, and distribution overlay (ranked and temporally aligned vs original)

# %%
# plot distributions for each metric
fig, ax = plt.subplots(1,3,figsize=(20,5))
kwargs = {'alpha':0.7, 'bins':100}
ax[0].hist(pubmed_results_df['r1'], **kwargs, label='pubmed')
ax[0].hist(ranked_temporal_pubmed_results_df['r1'], **kwargs, label='ranked temporal pubmed')
ax[0].legend()
ax[0].set_title('rouge-1 distribution')
ax[1].hist(pubmed_results_df['r2'], **kwargs, label='pubmed')
ax[1].hist(ranked_temporal_pubmed_results_df['r2'], **kwargs, label='ranked temporal pubmed')
ax[1].set_title('rouge-2 distribution')
ax[1].legend()
ax[2].hist(pubmed_results_df['rlsum'], **kwargs, label='pubmed')
ax[2].hist(ranked_temporal_pubmed_results_df['rlsum'], **kwargs, label='ranked temporal pubmed')
ax[2].set_title('rouge-Lsum distribution')
ax[2].legend()
plt.suptitle('Rouge Scores, Pre-Trained on Pubmed vs. Ranked Temporal Pubmed', y=1.05, size=16)
pass

# %%
# t-tests
print('overall:')
df1 = pubmed_results_df
df2 = ranked_temporal_pubmed_results_df
r1_pubmed = df1['r1']
r1_ranked_temporal = df2['r1']
r1_t_test = ttest_ind(r1_pubmed, r1_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-1 t-test:\n{r1_t_test}')
print('----')
r2_pubmed = df1['r2']
r2_ranked_temporal = df2['r2']
r2_t_test = ttest_ind(r2_pubmed, r2_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-2 t-test:\n{r2_t_test}')
print('----')
rl_pubmed = df1['rlsum']
rl_ranked_temporal = df2['rlsum']
rl_t_test = ttest_ind(rl_pubmed, rl_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-Lsum t-test:\n{rl_t_test}')
print('\n')

# long documents
print('documents > 4096 tokens:')
df1 = pubmed_results_df[pubmed_results_df['doc_len'] > 4096]
df2 = ranked_temporal_pubmed_results_df[ranked_temporal_pubmed_results_df['doc_len'] > 4096]
r1_pubmed = df1['r1']
r1_ranked_temporal = df2['r1']
r1_t_test = ttest_ind(r1_pubmed, r1_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-1 t-test:\n{r1_t_test}')
print('----')
r2_pubmed = df1['r2']
r2_ranked_temporal = df2['r2']
r2_t_test = ttest_ind(r2_pubmed, r2_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-2 t-test:\n{r2_t_test}')
print('----')
rl_pubmed = df1['rlsum']
rl_ranked_temporal = df2['rlsum']
rl_t_test = ttest_ind(rl_pubmed, rl_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-Lsum t-test:\n{rl_t_test}')
print('\n')

# short documents
print('documents < 4096 tokens:')
df1 = pubmed_results_df[pubmed_results_df['doc_len'] < 4096]
df2 = ranked_temporal_pubmed_results_df[ranked_temporal_pubmed_results_df['doc_len'] < 4096]
r1_pubmed = df1['r1']
r1_ranked_temporal = df2['r1']
r1_t_test = ttest_ind(r1_pubmed, r1_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-1 t-test:\n{r1_t_test}')
print('----')
r2_pubmed = df1['r2']
r2_ranked_temporal = df2['r2']
r2_t_test = ttest_ind(r2_pubmed, r2_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-2 t-test:\n{r2_t_test}')
print('----')
rl_pubmed = df1['rlsum']
rl_ranked_temporal = df2['rlsum']
rl_t_test = ttest_ind(rl_pubmed, rl_ranked_temporal, equal_var=False, alternative='two-sided')
print(f'Results for Rouge-Lsum t-test:\n{rl_t_test}')
print('\n')
print(len(df1))
print(len(df2))
# Out:
# overall:
# Results for Rouge-1 t-test:
# Ttest_indResult(statistic=-22.341468801835244, pvalue=1.4554083068798318e-108)
# ----
# Results for Rouge-2 t-test:
# Ttest_indResult(statistic=-20.575254823174788, pvalue=1.2601084234835975e-92)
# ----
# Results for Rouge-Lsum t-test:
# Ttest_indResult(statistic=60.89081433884656, pvalue=0.0)
#
#
# documents > 4096 tokens:
# Results for Rouge-1 t-test:
# Ttest_indResult(statistic=-17.49331512979433, pvalue=2.0746991282539481e-66)
# ----
# Results for Rouge-2 t-test:
# Ttest_indResult(statistic=-17.07354011180459, pvalue=1.8925223298680018e-63)
# ----
# Results for Rouge-Lsum t-test:
# Ttest_indResult(statistic=33.253658600988736, pvalue=1.0295606874320172e-216)
#
#
# documents < 4096 tokens:
# Results for Rouge-1 t-test:
# Ttest_indResult(statistic=-15.314184458756417, pvalue=2.98853555764949e-52)
# ----
# Results for Rouge-2 t-test:
# Ttest_indResult(statistic=-13.980888172793083, pvalue=6.1423881919168e-44)
# ----
# Results for Rouge-Lsum t-test:
# Ttest_indResult(statistic=51.5510779985484, pvalue=0.0)
#
#
# 4316
# 4316

# %% [markdown]
# ## Evaluation of performance with resepect to document length

# %%
# Import test data
with open('../data/json_test.txt') as json_file:
    test = json.load(json_file)
test = test['data']

# %%
tokenizer = AutoTokenizer.from_pretrained("allenai/longformer-base-4096", add_prefix_space=True)
doc_len = []
for i in test:
    input_ = i['article_text']
    length = len(tokenizer(input_, is_split_into_words=True, return_tensors='pt', truncation=False)[0])
    doc_len.append(length)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4604 > 4096). Running this sequence through the model will result in indexing errors

# %%
pubmed_results_df['doc_len'] = doc_len
ranked_pubmed_results_df['doc_len'] = doc_len
ranked_temporal_pubmed_results_df['doc_len'] = doc_len

# %%
df = pubmed_results_df
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -3.343158252369734e-06
# r2 coefficient: -2.0722073712222936e-06
# rlsum coefficient: -2.8078987838828495e-06
#
# r1 Mean: 0.2924441052368615
# r2 Mean: 0.0819560900711394
# rlsum Mean: 0.26402545872119126

# %%
df = ranked_pubmed_results_df
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -4.1566996390307986e-06
# r2 coefficient: -2.3458039254346937e-06
# rlsum coefficient: -1.8414285999977122e-06
#
# r1 Mean: 0.3239331226612312
# r2 Mean: 0.09860652155121755
# rlsum Mean: 0.20558567502032113

# %%
df = ranked_temporal_pubmed_results_df
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -2.038313673473916e-06
# r2 coefficient: -1.6427307875688012e-06
# rlsum coefficient: -8.173778544277893e-07
#
# r1 Mean: 0.3193323718312698
# r2 Mean: 0.09813109076147772
# rlsum Mean: 0.20281353351246542

# %% [markdown]
# # Long Documents (> 4096 tokens)

# %%
df = pubmed_results_df
df = df[df['doc_len'] > 4096]
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -2.1182221656433556e-06
# r2 coefficient: -1.1490248525744964e-06
# rlsum coefficient: -1.7041933943419551e-06
#
# r1 Mean: 0.2776900621641823
# r2 Mean: 0.07211755638988462
# rlsum Mean: 0.2512577555402491

# %%
df = ranked_pubmed_results_df
df = df[df['doc_len'] > 4096]
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -2.2566652019496787e-06
# r2 coefficient: -1.1386235981078786e-06
# rlsum coefficient: -5.531762019874385e-07
#
# r1 Mean: 0.306469165452179
# r2 Mean: 0.08836178570621386
# rlsum Mean: 0.19701140967855002

# %%
df = ranked_temporal_pubmed_results_df
df = df[df['doc_len'] > 4096]
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -1.1834238695900182e-06
# r2 coefficient: -8.943638085968347e-07
# rlsum coefficient: 1.9409261389711085e-07
#
# r1 Mean: 0.31132423438530193
# r2 Mean: 0.0915797686358872
# rlsum Mean: 0.1981307878040451

# %% [markdown]
# # Short documents (< 4096 tokens)

# %%
df = pubmed_results_df
df = df[df['doc_len'] < 4096]
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -4.510964539763794e-06
# r2 coefficient: -2.855638346973319e-06
# rlsum coefficient: -3.6564158974783634e-06
#
# r1 Mean: 0.3004294088352826
# r2 Mean: 0.08728198787068918
# rlsum Mean: 0.27093705135214224

# %%
df = ranked_pubmed_results_df
df = df[df['doc_len'] < 4096]
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -1.2327508277514437e-05
# r2 coefficient: -7.485401477001573e-06
# rlsum coefficient: -8.430771889841945e-06
#
# r1 Mean: 0.33340407311684844
# r2 Mean: 0.10416585185192469
# rlsum Mean: 0.21023832548158786

# %%
df = ranked_temporal_pubmed_results_df
df = df[df['doc_len'] < 4096]
fig, axs = plt.subplots(3,1, figsize = (20,10))
axs[0].set_title('rouge1')
axs[0].scatter(df.doc_len, df.r1, alpha=0.5)
m1, b1 = np.polyfit(df.doc_len, df.r1, 1)
axs[0].plot(df.doc_len, m1*df.doc_len + b1, c='orange')

# rouge 2
axs[1].set_title('rouge2')
axs[1].scatter(df.doc_len, df.r2, alpha=0.5)
m4, b4 = np.polyfit(df.doc_len, df.r2, 1)
axs[1].plot(df.doc_len, m4*df.doc_len + b4, c='orange')

# rouge lsum
axs[2].set_title('rougelsum')
axs[2].scatter(df.doc_len, df.rlsum, alpha=0.5)
m7, b7 = np.polyfit(df.doc_len, df.rlsum, 1)
axs[2].plot(df.doc_len, m7*df.doc_len + b7, c='orange')
plt.tight_layout()

print(f'r1 coefficient: {m1}')
print(f'r2 coefficient: {m4}')
print(f'rlsum coefficient: {m7}')
print('')
print(f'r1 Mean: {df.r1.mean()}')
print(f'r2 Mean: {df.r2.mean()}')
print(f'rlsum Mean: {df.rlsum.mean()}')
# Out:
# r1 coefficient: -6.625772040090433e-06
# r2 coefficient: -5.775603125011945e-06
# rlsum coefficient: -6.52473855881577e-06
#
# r1 Mean: 0.32367933755973805
# r2 Mean: 0.10168594517456639
# rlsum Mean: 0.20535806419079145
